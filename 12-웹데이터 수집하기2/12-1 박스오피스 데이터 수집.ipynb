# %% [markdown]
# # 일별 박스오피스 가져오기 (교안)

# %%
import requests
import datetime as dt
from pandas import DataFrame

# %%
url='http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json'

API_KEY='ec543aa04d8784df83b875b5227ba454'

date=dt.datetime.now()-dt.timedelta(days=1)
yesterday=date.strftime('%Y%m%d')
yesterday
# Out:
# '20251104'

# %%
with requests.Session() as session:
    session.headers.update({
        'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36'
    })

    r=session.get(url,params={'key':API_KEY, 'targetDt':yesterday})     # GET 방식에는 딕셔너리 형태로 params 제공

    # 정상코드 출력이 안되면 에러 발생시키기
    if r.status_code != 200:
        msg='[%d Error] %s 에러가 발생함'%(r.status_code,r.reason)
        raise Exception(msg)
    
    print(r)
# Out:
# <Response [200]>

# %%
mydict=r.json()
print(mydict)
# Out:
# {'boxOfficeResult': {'boxofficeType': '일별 박스오피스', 'showRange': '20251104~20251104', 'dailyBoxOfficeList': [{'rnum': '1', 'rank': '1', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20253852', 'movieNm': '퍼스트 라이드', 'openDt': '2025-10-29', 'salesAmt': '215330100', 'salesShare': '28.4', 'salesInten': '-15052260', 'salesChange': '-6.5', 'salesAcc': '3827605550', 'audiCnt': '23991', 'audiInten': '-1187', 'audiChange': '-4.7', 'audiAcc': '417973', 'scrnCnt': '1016', 'showCnt': '3437'}, {'rnum': '2', 'rank': '2', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20256757', 'movieNm': '극장판 체인소 맨: 레제편', 'openDt': '2025-09-24', 'salesAmt': '145836700', 'salesShare': '19.2', 'salesInten': '-15110280', 'salesChange': '-9.4', 'salesAcc': '29873971080', 'audiCnt': '14654', 'audiInten': '-1471', 'audiChange': '-9.1', 'audiAcc': '2824910', 'scrnCnt': '630', 'showCnt': '2218'}, {'rnum': '3', 'rank': '3', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20257570', 'movieNm': '8번 출구', '
# ...

# %%
df=DataFrame(mydict['boxOfficeResult']['dailyBoxOfficeList'])
df
# Out:
#   rnum rank rankInten rankOldAndNew   movieCd           movieNm      openDt  \
# 0    1    1         0           OLD  20253852           퍼스트 라이드  2025-10-29
# 1    2    2         0           OLD  20256757    극장판 체인소 맨: 레제편  2025-09-24
# 2    3    3         0           OLD  20257570             8번 출구  2025-10-22
# 3    4    4         1           OLD  20247429            세계의 주인  2025-10-22
# 4    5    5        -1           OLD  20090284              코렐라인  2009-05-21
# 5    6    6         0           OLD  20243561            어쩔수가없다  2025-09-24
# 6    7    7         0           OLD  20253289  극장판 귀멸의 칼날: 무한성편  2025-08-22
# 7    8    8         0           OLD  20228988                보스  2025-10-03
# 8    9    9         1           OLD  20225855        하얀 차를 탄 여자  2025-10-29
# 9   10   10        -1           OLD  20256397      원 배틀 애프터 어나더  2025-10-01
#
#     salesAmt salesShare salesInten salesChange     salesAcc audiCnt audiInten  \
# ...

# %% [markdown]
# # 주차별 박스오피스 가져오기 (연습)

# %%
import requests
import datetime as dt
from pandas import DataFrame

# %%
url='http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json'

API_KEY='ec543aa04d8784df83b875b5227ba454'

date=dt.datetime.now()-dt.timedelta(days=7)
lastweek=date.strftime('%Y%m%d')
lastweek
# Out:
# '20251029'

# %%
with requests.Session() as session:
    session.headers.update({
        'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36'
    })

    r=session.get(url,params={'key':API_KEY, 'targetDt':lastweek})     # GET 방식에는 딕셔너리 형태로 params 제공

    # 정상코드 출력이 안되면 에러 발생시키기
    if r.status_code != 200:
        msg='[%d Error] %s 에러가 발생함'%(r.status_code,r.reason)
        raise Exception(msg)
    
    print(r)
# Out:
# <Response [200]>

# %%
mydict=r.json()
print(mydict)
# Out:
# {'boxOfficeResult': {'boxofficeType': '주말 박스오피스', 'showRange': '20251031~20251102', 'yearWeekTime': '202544', 'weeklyBoxOfficeList': [{'rnum': '1', 'rank': '1', 'rankInten': '35', 'rankOldAndNew': 'OLD', 'movieCd': '20253852', 'movieNm': '퍼스트 라이드', 'openDt': '2025-10-29', 'salesAmt': '2231316010', 'salesShare': '28.8', 'salesInten': '2214344110', 'salesChange': '13047.1', 'salesAcc': '3381893090', 'audiCnt': '230777', 'audiInten': '229535', 'audiChange': '18481.1', 'audiAcc': '368804', 'scrnCnt': '1165', 'showCnt': '13289'}, {'rnum': '2', 'rank': '2', 'rankInten': '-1', 'rankOldAndNew': 'OLD', 'movieCd': '20256757', 'movieNm': '극장판 체인소 맨: 레제편', 'openDt': '2025-09-24', 'salesAmt': '1548106220', 'salesShare': '20.0', 'salesInten': '-820648870', 'salesChange': '-34.6', 'salesAcc': '29567187400', 'audiCnt': '147463', 'audiInten': '-72206', 'audiChange': '-32.9', 'audiAcc': '2794131', 'scrnCnt': '817', 'showCnt': '8149'}, {'rnum': '3', 'rank': '3', 'rankInten': '-1', 'rankOldAndNew': 'OLD
# ...

# %%
df=DataFrame(mydict['boxOfficeResult']['weeklyBoxOfficeList'])
df
# Out:
#   rnum rank rankInten rankOldAndNew   movieCd             movieNm      openDt  \
# 0    1    1        35           OLD  20253852             퍼스트 라이드  2025-10-29
# 1    2    2        -1           OLD  20256757      극장판 체인소 맨: 레제편  2025-09-24
# 2    3    3        -1           OLD  20257570               8번 출구  2025-10-22
# 3    4    4         0           NEW  20259147          케이팝 데몬 헌터스  2025-10-31
# 4    5    5        -1           OLD  20090284                코렐라인  2009-05-21
# 5    6    6         0           OLD  20253289    극장판 귀멸의 칼날: 무한성편  2025-08-22
# 6    7    7        -2           OLD  20243561              어쩔수가없다  2025-09-24
# 7    8    8         1           OLD  20247429              세계의 주인  2025-10-22
# 8    9    9         0           NEW  20259058  신세기 에반게리온 극장판 사도신생  2025-10-31
# 9   10   10        -3           OLD  20257658     극장판 주술회전: 회옥·옥절  2025-10-16
#
#      salesAmt salesShare  salesInten salesChange     salesAcc audiCnt  \
# ...
